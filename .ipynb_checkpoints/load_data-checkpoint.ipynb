# %%
import pymongo
import pandas as pd
import json

# %%
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# %%
db = client.lawn_mower_inventory
collection = db.lawn_mower

# %%
mower_data_cleaned = "mower_data_cleaned.csv"
jonathan_df = pd.read_csv(mower_data_cleaned)
jonathan_df
# Out:
#                                                  title    price  \
# 0    Craftsman M215 159cc 21-Inch 3-in-1 High-Wheel...  $292.79
# 1    Craftsman M105 140cc 21-Inch 3-in-1 Gas Powere...  $229.00
# 2    GreenWorks 20-Inch 12 Amp Corded Electric Lawn...  $188.19
# 3    Greenworks 16-Inch 40V Cordless Lawn Mower, 4....  $282.45
# 4    American Lawn Mower Company 1204-14 14-Inch 4-...   $73.11
# ..                                                 ...      ...
# 149  Sun Joe MJ501M Manual Reel Mower w/Grass Catch...   $70.99
# 150  Sun Joe iON16LM 40-Volt 16-Inch Brushless Cord...  $197.53
# 151  BLACK+DECKER Lawn Mower, Corded, 13-Amp, 20-In...  $174.22
# 152  Goplus 14-Inch 12 Amp Lawn Mower w/Grass Bag F...   $89.00
# 153  BLACK+DECKER BEMW472ES Electric Mower 15" Lawn...  $122.56
#
#                                               imageUrl  \
# 0    https://images-na.ssl-images-amazon.com/images...
# 1    https://images-na.ssl-images-amazon.com/images...
# ...

# %%
jonathan_json = jonathan_df.to_json(orient='records')
jonathan_json
# Out:
# '[{"title":"Craftsman M215 159cc 21-Inch 3-in-1 High-Wheeled FWD Self-Propelled Gas Powered Lawn Mower with Bagger","price":"$292.79","imageUrl":"https:\\/\\/images-na.ssl-images-amazon.com\\/images\\/I\\/41XYwvAvKUL._SL160_.jpg","pageUrl":"https:\\/\\/www.amazon.com\\/M215-159cc-21-Inch-High-Wheeled-Self-Propelled\\/dp\\/B07NW9JR3D","rating":4.0,"totalReview":63.0,"source":"Amazon"},{"title":"Craftsman M105 140cc 21-Inch 3-in-1 Gas Powered Push Lawn Mower with Bagger","price":"$229.00","imageUrl":"https:\\/\\/images-na.ssl-images-amazon.com\\/images\\/I\\/41JutTAgERL._SL160_.jpg","pageUrl":"https:\\/\\/www.amazon.com\\/Craftsman-M105-140cc-21-Inch-Powered\\/dp\\/B07NW8SP6H","rating":4.0,"totalReview":69.0,"source":"Amazon"},{"title":"GreenWorks 20-Inch 12 Amp Corded Electric Lawn Mower 25022","price":"$188.19","imageUrl":"https:\\/\\/images-na.ssl-images-amazon.com\\/images\\/I\\/51acxmsF7AL._SL160_.jpg","pageUrl":"https:\\/\\/www.amazon.com\\/GreenWorks-20-Inch-Corded-Electric-2502
# ...

# %%
parsed = json.loads(jonathan_json)
print(json.dumps(parsed, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "imageUrl": "https://images-na.ssl-images-amazon.com/images/I/41XYwvAvKUL._SL160_.jpg",
#         "pageUrl": "https://www.amazon.com/M215-159cc-21-Inch-High-Wheeled-Self-Propelled/dp/B07NW9JR3D",
#         "price": "$292.79",
#         "rating": 4.0,
#         "source": "Amazon",
#         "title": "Craftsman M215 159cc 21-Inch 3-in-1 High-Wheeled FWD Self-Propelled Gas Powered Lawn Mower with Bagger",
#         "totalReview": 63.0
#     },
#     {
#         "imageUrl": "https://images-na.ssl-images-amazon.com/images/I/41JutTAgERL._SL160_.jpg",
#         "pageUrl": "https://www.amazon.com/Craftsman-M105-140cc-21-Inch-Powered/dp/B07NW8SP6H",
#         "price": "$229.00",
#         "rating": 4.0,
#         "source": "Amazon",
#         "title": "Craftsman M105 140cc 21-Inch 3-in-1 Gas Powered Push Lawn Mower with Bagger",
#         "totalReview": 69.0
#     },
#     {
#         "imageUrl": "https://images-na.ssl-images-amazon.com/images/I/51acxmsF7AL._SL160_.jpg",
# ...

# %%
db.collection.insert_many(jonathan_json)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-5e2216e151e2> in <module>
# ----> 1 db.collection.insert_many(jonathan_json)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     755         write_concern = self._write_concern_for(session)
#     756         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 757         blk.ops = [doc for doc in gen()]
#     758         blk.execute(write_concern, session=session)
#     759         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py in <listcomp>(.0)
#     755         write_concern = self._write_concern_for(session)
#     756         blk = _Bulk(self, ordered, bypass_document_validation)
# ...
